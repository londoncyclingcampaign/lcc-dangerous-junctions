# %% [markdown]
# # Collision stats
#
# __June 2026__
#
# Answering 2 key questions:
# - What fraction of casualties are female?
# - What fraction of casualties at a junction are female?

# %%
import yaml
import pandas as pd
import numpy as np

from yaml import Loader
from scipy.stats import binomtest
from statsmodels.stats.proportion import proportion_confint

# %% [markdown]
# ## Read in collision & casualty data

# %%
params = yaml.load(open("../params.yaml", 'r'), Loader=Loader)
collisions = pd.read_csv('../data/pedestrian-and-cyclist-collisions.csv')

casualties = pd.read_csv('../data/casualties.csv')
casualties['year'] = casualties['collision_id'].apply(lambda x: int(str(x)[0:4]))

casualties

print('Junction types:')
print(params['valid_junction_types'])

collisions.head(3)
# Out:
# Junction types:
# ['roundabout', 'mini_roundabout', 't_or_staggered_junction', 'slip_road', 'crossroads', 'multi_junction', 'other_junction', 'unknown']
#    raw_collision_id      borough   easting  northing  \
# 0        1240486807       CAMDEN  527188.0  184782.0
# 1        1240486828     LEWISHAM  536554.0  178468.0
# 2        1240486841  WESTMINSTER  529084.0  181324.0
#
#                                             location collision_severity  \
# 0  ON BELSIZE PARK GARDENS, NEAR THE JUNCTION WIT...             slight
# 1  ON GROVE STREET, NEAR THE JUNCTION WITH OXESTA...             slight
# 2  LOCATION UNCERTAIN GREAT PORTLAND STREET, NEAR...             slight
#
#            junction_detail   road_type        date      time  ...  \
# 0  t_or_staggered_junction  Single Cwy  2024-01-01  01:00:00  ...
# 1       no_junction_in_20m  roundabout  2024-01-01  00:35:00  ...
# 2               crossroads    Dual Cwy  2024-01-01  02:15:00  ...
#
#    max_pedestrian_severity  male_cyclist_casualties  \
# 0                      NaN                        0
# 1                   slight                        0
# 2                   slight                        0
#
#    female_cyclist_casualties  unknown_gender_cyclist_casualties  \
# 0                          0                                  1
# 1                          0                                  0
# 2                          0                                  0
#
#    male_pedestrian_casualties  female_pedestrian_casualties  \
# 0                           0                             0
# 1                           0                             1
# 2                           0                             2
#
#    unknown_gender_pedestrian_casualties recency_weight  is_cyclist_collision  \
# 0                                     0       1.113943                  True
# 1                                     0       1.113943                 False
# 2                                     0       1.113943                 False
#
#    is_pedestrian_collision
# 0                    False
# 1                     True
# 2                     True
#
# [3 rows x 31 columns]

# %%
junction_collision_ids = collisions['raw_collision_id'].tolist()
junction_collision_ids[0:5]
# Out:
# [1240486807, 1240486828, 1240486841, 1240486874, 1240486897]

# %%
# filtering mask
casualty_mask = casualties['mode_of_travel'] == 'pedal_cycle'
severity_mask = (
    (casualties['casualty_severity'] == 'serious') |
    (casualties['casualty_severity'] == 'fatal')
)
junction_mask = casualties['raw_collision_id'].isin(junction_collision_ids)

# %%
all = (
    casualties[casualty_mask]
    .groupby(['casualty_gender', 'casualty_severity'])['raw_collision_id']
    .count()
    .reset_index()
    .pivot(
        index='casualty_gender',
        columns='casualty_severity',
        values='raw_collision_id'
    )
    .fillna(0)
    .reset_index()
    # .T
)
all['type'] = 'all'

at_junction = (
    casualties[casualty_mask & junction_mask]
    .groupby(['casualty_gender', 'casualty_severity'])['raw_collision_id']
    .count()
    .reset_index()
    .pivot(
        index='casualty_gender',
        columns='casualty_severity',
        values='raw_collision_id'
    )
    .fillna(0)
    .reset_index()
    # .T
)
at_junction['type'] = 'at_junction'

casualty_counts = pd.concat([
    all,
    at_junction
])

severities = ['fatal', 'serious', 'slight']
for s in severities:
    casualty_counts[f'%_{s}'] = 100 * (
        casualty_counts[s] / casualty_counts[severities].sum(axis=1)
    )

casualty_counts
# Out:
# casualty_severity casualty_gender  fatal  serious   slight         type  \
# 0                          1 Male   16.0   1118.0   5930.0          all
# 1                        2 Female    6.0    327.0   1879.0          all
# 2                          Female   13.0   1284.0   5400.0          all
# 3                            Male   32.0   4264.0  17866.0          all
# 4                         Unknown    0.0     14.0    598.0          all
# 0                          1 Male   15.0    898.0   4705.0  at_junction
# 1                        2 Female    5.0    265.0   1519.0  at_junction
# 2                          Female   11.0   1016.0   4532.0  at_junction
# 3                            Male   24.0   3274.0  14681.0  at_junction
# 4                         Unknown    0.0     11.0    488.0  at_junction
#
# casualty_severity   %_fatal  %_serious   %_slight
# 0                  0.226501  15.826727  83.946772
# 1                  0.271248  14.783002  84.945750
# 2                  0.194117  19.172764  80.633119
# 3                  0.144391  19.240141  80.615468
# 4                  0.000000   2.287582  97.712418
# 0                  0.266999  15.984336  83.748665
# 1                  0.279486  14.812745  84.907770
# 2                  0.197877  18.276668  81.525454
# 3                  0.133489  18.210134  81.656377
# 4                  0.000000   2.204409  97.795591

# %%
all = (
    casualties[casualty_mask]
    .groupby(['casualty_gender', 'casualty_severity'])['raw_collision_id']
    .count()
    .reset_index()
    .pivot(
        index='casualty_severity',
        columns='casualty_gender',
        values='raw_collision_id'
    )
    .fillna(0)
    .reset_index()
)
all['type'] = 'all'

at_junction = (
    casualties[casualty_mask & junction_mask]
    .groupby(['casualty_gender', 'casualty_severity'])['raw_collision_id']
    .count()
    .reset_index()
    .pivot(
        index='casualty_severity',
        columns='casualty_gender',
        values='raw_collision_id'
    )
    .fillna(0)
    .reset_index()
)
at_junction['type'] = 'at_junction'

casualty_counts = pd.concat([
    all,
    at_junction
]).set_index('type').reset_index()

genders = ['Female', 'Male', 'Unknown']
for g in genders:
    casualty_counts[f'%_{g}'] = np.round(100 * (
        casualty_counts[g] / casualty_counts[genders].sum(axis=1)
    ), 2)

casualty_counts
# Out:
# casualty_gender         type casualty_severity  1 Male  2 Female  Female  \
# 0                        all             fatal    16.0       6.0    13.0
# 1                        all           serious  1118.0     327.0  1284.0
# 2                        all            slight  5930.0    1879.0  5400.0
# 3                at_junction             fatal    15.0       5.0    11.0
# 4                at_junction           serious   898.0     265.0  1016.0
# 5                at_junction            slight  4705.0    1519.0  4532.0
#
# casualty_gender     Male  Unknown  %_Female  %_Male  %_Unknown
# 0                   32.0      0.0     28.89   71.11       0.00
# 1                 4264.0     14.0     23.09   76.66       0.25
# 2                17866.0    598.0     22.63   74.87       2.51
# 3                   24.0      0.0     31.43   68.57       0.00
# 4                 3274.0     11.0     23.62   76.12       0.26
# 5                14681.0    488.0     23.00   74.52       2.48

# %%
casualty_counts[
    (casualty_counts['type'] == 'at_junction')
    & (casualty_counts['casualty_severity'] != 'fatal')
][genders].sum().sum()
# Out:
# np.float64(20263.0)

# %%
# at junction only
type_mask = casualty_counts['type'] == 'at_junction'

female_non_fatal = int(casualty_counts[
    type_mask
    & (casualty_counts['casualty_severity'] != 'fatal')
]['Female'].sum())

non_fatal = int(casualty_counts[
    type_mask
    & (casualty_counts['casualty_severity'] != 'fatal')
][genders].sum().sum())

female_fatals = int(casualty_counts[
    type_mask
    & (casualty_counts['casualty_severity'] == 'fatal')
]['Female'].sum())

fatals = int(casualty_counts[
    type_mask
    & (casualty_counts['casualty_severity'] == 'fatal')
][genders].sum().sum())

print(female_non_fatal, non_fatal, female_fatals, fatals)

baseline_female_rate = female_non_fatal / non_fatal  # ~0.23
print(baseline_female_rate)

result = binomtest(k=10, n=fatals, p=baseline_female_rate, alternative='greater')
low, high = proportion_confint(count=10, nobs=fatals, method='wilson')

print(f"p-value: {result.pvalue:.3f}")
print(f"95% CI: {low:.1%} – {high:.1%}")
# Out:
# 4620 20263 10 31
# 0.22800177663722054
# p-value: 0.149
# 95% CI: 18.6% – 49.9%

# %%
from scipy.stats import chi2_contingency

# Fatal vs non-fatal × Female vs Male (exclude Unknown)
table = [
    [10, 21],         # fatal:     [female, male]
    [3742+878, 12357+2828]  # non-fatal: [female, male]
]

chi2, p, dof, expected = chi2_contingency(table)
print(f"Chi-squared: {chi2:.3f}, p-value: {p:.3f}")
print(f"Expected frequencies:\n{expected}")
# Out:
# Chi-squared: 0.926, p-value: 0.336
# Expected frequencies:
# [[7.23583384e+00 2.37641662e+01]
#  [4.62276417e+03 1.51822358e+04]]

# %%
from scipy.stats import fisher_exact

odds_ratio, p_fisher = fisher_exact(table, alternative='greater')
print(f"Fisher's exact p-value: {p_fisher:.3f}")
print(f"Odds ratio: {odds_ratio:.2f}")
# Out:
# Fisher's exact p-value: 0.167
# Odds ratio: 1.57

# %% [markdown]
# ### Percentage of serious or fatal collisions at a junction?
#
# Cyclist and last 5 years.

# %%
mask = (
    df['is_cyclist_collision']
    &
    ((df['max_cyclist_severity'] == 'serious') | (df['max_cyclist_severity'] == 'fatal'))
)

(
    df[mask & df['junction_detail'].isin(params['valid_junction_types'])]
    .raw_collision_id.nunique()
    /
    df[mask].raw_collision_id.nunique()
) * 100
# Out:
# 98.55499063419856

# %% [markdown]
# ### Above, but cut by year

# %%
# check the trend
(
    df[mask & df['junction_detail'].isin(params['valid_junction_types'])].groupby('year')['raw_collision_id'].nunique()
    /
    df[mask].groupby('year')['raw_collision_id'].nunique()
    *
    100
)
# Out:
# year
# 2019    75.515464
# 2020    77.739331
# 2021    76.653307
# 2022    79.060665
# 2023    79.380342
# Name: raw_collision_id, dtype: float64

# %% [markdown]
# ### Finally, do the stats move much if we filter out unknown?

# %%
# exclude unknown
junction_types = [
    'roundabout', 'mini_roundabout', 't_or_staggered_junction',
    'slip_road', 'crossroads', 'multi_junction', 'other_junction'
]

(
    df[mask & df['junction_detail'].isin(junction_types)]
    .raw_collision_id.nunique()
    /
    df[mask].raw_collision_id.nunique()
) * 100
# Out:
# 74.40747988693194

# %% [markdown]
# ## Q2 - What fraction of casualties are female?

# %%
casualties = pd.read_csv('../data/casualties.csv')
casualties['year'] = casualties['collision_id'].apply(lambda x: int(str(x)[0:4]))

casualties.head()
# Out:
#    raw_collision_id  casualty_id   casualty_class casualty_gender  \
# 0        1240486807            1  driver_or_rider         Unknown
# 1        1240486821            1  driver_or_rider            Male
# 2        1240486821            2        passenger         Unknown
# 3        1240486824            1  driver_or_rider          Female
# 4        1240486825            1  driver_or_rider            Male
#
#    number_of_casualties casualty_severity mode_of_travel   collision_id  year
# 0                     1            slight    pedal_cycle  2024010486807  2024
# 1                     1            slight            car  2024010486821  2024
# 2                     1            slight            car  2024010486821  2024
# 3                     1            slight            car  2024010486824  2024
# 4                     1            slight     Motorcycle  2024010486825  2024

# %%
casualty_mask = casualties['mode_of_travel'] == 'pedal_cycle'
severity_mask = (
    (casualties['casualty_severity'] == 'serious') |
    (casualties['casualty_severity'] == 'fatal')
)

# %% [markdown]
# ### % Female, for all severities

# %%
display(
    casualties[casualty_mask].groupby('casualty_gender')['raw_collision_id'].count()
)

(
    casualties[casualty_mask]
    .groupby('casualty_gender')['raw_collision_id']
    .count()
    /
    casualties[casualty_mask]['raw_collision_id']
    .count()
    *
    100
)
# Out:
# casualty_gender
# Female      5557
# Male       18721
# Unknown      559
# Name: raw_collision_id, dtype: int64
# casualty_gender
# Female     22.373878
# Male       75.375448
# Unknown     2.250674
# Name: raw_collision_id, dtype: float64

# %% [markdown]
# #### Above, but broken down by year

# %%
gender_by_year = (
    casualties[casualty_mask]
    .groupby(['year', 'casualty_gender'])
    ['raw_collision_id']
    .count()
    .reset_index(name='count')
    .pivot(columns='casualty_gender', index='year', values='count')
)

gender_by_year['%_female'] = gender_by_year['Female'] / gender_by_year.sum(axis=1)
gender_by_year['%_male'] = gender_by_year['Male'] / gender_by_year.sum(axis=1)
gender_by_year['%_unknown'] = gender_by_year['Unknown'] / gender_by_year.sum(axis=1)

gender_by_year
# Out:
# casualty_gender  Female  Male  Unknown  %_female    %_male  %_unknown
# year
# 2020               1140  3586       63  0.238046  0.748762   0.013152
# 2021               1194  3971      112  0.226265  0.752479   0.021220
# 2022               1124  3855      112  0.220782  0.757186   0.021995
# 2023               1034  3644      124  0.215327  0.758816   0.025817
# 2024               1065  3665      148  0.218327  0.751299   0.030334

# %% [markdown]
# ### % Female, for serious or fatal

# %%
display(
    casualties[casualty_mask & severity_mask].groupby('casualty_gender')['raw_collision_id'].count()
)

(
    casualties[casualty_mask & severity_mask]
    .groupby('casualty_gender')['raw_collision_id']
    .count()
    /
    casualties[casualty_mask & severity_mask]['raw_collision_id']
    .count()
    *
    100
)
# Out:
# casualty_gender
# Female     1072
# Male       3529
# Unknown      12
# Name: raw_collision_id, dtype: int64
# casualty_gender
# Female     23.238673
# Male       76.501192
# Unknown     0.260134
# Name: raw_collision_id, dtype: float64

# %% [markdown]
# #### Above, but broken down by year

# %%
gender_by_year = (
    casualties[casualty_mask & severity_mask]
    .groupby(['year', 'casualty_gender'])
    ['raw_collision_id']
    .count()
    .reset_index(name='count')
    .pivot(columns='casualty_gender', index='year', values='count')
)

gender_by_year['%_female'] = gender_by_year['Female'] / gender_by_year.sum(axis=1)
gender_by_year['%_male'] = gender_by_year['Male'] / gender_by_year.sum(axis=1)

gender_by_year
# Out:
# casualty_gender  Female  Male  Unknown  %_female    %_male
# year
# 2020                209   658        1  0.240783  0.757854
# 2021                238   758        3  0.238238  0.758578
# 2022                234   789        4  0.227848  0.768087
# 2023                216   722        3  0.229543  0.767082
# 2024                225   767        2  0.226358  0.771454

# %%
casualties[casualty_mask].to_csv('../data/cyclist_casualties.csv', index=False)

# %% [markdown]
# ### Bootstrapping.

# %%
N = 10000
c = casualties[casualty_mask]

bootstapped_ratios = []
for n in range(N):
    c_sampled = c.sample(n=len(c), replace=True).copy()

    ratios = (
        c_sampled[severity_mask]
        .groupby('casualty_gender')['raw_collision_id']
        .count()
        .reset_index(name='severe')
    ).merge(
        (
            c_sampled[~severity_mask]
            .groupby('casualty_gender')['raw_collision_id']
            .count()
            .reset_index(name='slight')
        ),
        how='left',
        on='casualty_gender'
    )

    ratios['ratio'] = ratios['severe'] / (ratios['severe'] + ratios['slight'])
    ratios['run'] = n

    bootstapped_ratios.append(ratios)

bootstapped_ratios = pd.concat(bootstapped_ratios)

bootstapped_ratios
# Out:
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# ...
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[severity_mask]
# /var/folders/k6/t1sgvvr92r73vcstvdghnvkm0000gn/T/ipykernel_30313/1871055784.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c_sampled[~severity_mask]
#    casualty_gender  severe  slight     ratio   run
# 0           Female    1190    4451  0.210956     0
# 1             Male    3664   14953  0.196809     0
# 2          Unknown      13     566  0.022453     0
# 0           Female    1126    4330  0.206378     1
# 1             Male    3752   15080  0.199235     1
# ..             ...     ...     ...       ...   ...
# 1             Male    3723   15026  0.198571  9998
# 2          Unknown      17     552  0.029877  9998
# 0           Female    1107    4439  0.199603  9999
# 1             Male    3773   14991  0.201077  9999
# 2          Unknown      19     508  0.036053  9999
#
# [30000 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(
    data=bootstapped_ratios[
        bootstapped_ratios['casualty_gender'] != 'Unknown'
    ],
    x='ratio',
    hue='casualty_gender',
    kind='kde',
    fill=True
);
# plt.xlim(0, .25)
